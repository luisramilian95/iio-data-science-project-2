# %%
import pandas as pd
import requests 

request = requests.get("https://ja2v6xao2d.execute-api.us-east-2.amazonaws.com/dev/fetch")

json_data = request.text

dataset = pd.read_json(json_data,dtype='unicode',convert_dates=False)

dataset
# Out:
#      booster_id              booster_name card_number
# 0             1   Absolute Powerforce 5D1  ABPF-EN000  \
# 1             2   Absolute Powerforce 5D1  ABPF-EN001
# 2             3   Absolute Powerforce 5D1  ABPF-EN002
# 3             4   Absolute Powerforce 5D1  ABPF-EN003
# 4             5   Absolute Powerforce 5D1  ABPF-EN004
# ...         ...                       ...         ...
# 3041       3042  The Shining Darkness 5D1  TSHD-EN095
# 3042       3043  The Shining Darkness 5D1  TSHD-EN096
# 3043       3044  The Shining Darkness 5D1  TSHD-EN097
# 3044       3045  The Shining Darkness 5D1  TSHD-EN098
# 3045       3046  The Shining Darkness 5D1  TSHD-EN099
#
#                         card_name               card_type  card_rarity
# 0         Gravekeeper's Priestess          Effect Monster   Super Rare  \
# 1                      Unicycular          Normal Monster       Common
# 2                         Bicular          Effect Monster       Common
# 3                        Tricular          Effect Monster       Common
# 4                  Drill Synchron           Tuner Monster         Rare
# ...                           ...                     ...          ...
# 3041                  Hydro Genex  Synchro/Effect Monster   Super Rare
# 3042  Ally of Justice Light Gazer  Synchro/Effect Monster   Super Rare
# 3043                Genex Neutron          Effect Monster  Secret Rare
# 3044          Infernity Destroyer          Effect Monster  Secret Rare
# 3045         Koa'ki Meiru Bergzak          Effect Monster  Secret Rare
#
#      card_attribute card_sub_type card_level card_attack card_defense
# 0              None                     Dark         3.0       1000.0  \
# 1              None                    Earth         1.0        100.0
# 2              None                    Earth         2.0        200.0
# 3              None                    Earth         3.0        300.0
# 4              None                    Earth         3.0        800.0
# ...             ...           ...        ...         ...          ...
# 3041           None                    Water         6.0       2300.0
# 3042           None                     Dark         8.0       2400.0
# 3043           None                    Light         4.0       1800.0
# 3044           None                     Dark         6.0       2300.0
# 3045           None                    Earth         4.0       2000.0
#
#      card_text
# 0       1500.0
# 1        100.0
# 2        200.0
# 3        300.0
# 4        300.0
# ...        ...
# 3041    1800.0
# 3042    1600.0
# 3043    1200.0
# 3044    1000.0
# 3045     200.0
#
# [3046 rows x 12 columns]
