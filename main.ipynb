# %%
import pandas as pd
import requests 

request = requests.get("https://ja2v6xao2d.execute-api.us-east-2.amazonaws.com/dev/fetch")

json_data = request.text

dataset = pd.read_json(json_data,dtype='unicode',convert_dates=False)

dataset
# Out:
#      booster_id             booster_name card_number
# 0             1  Absolute Powerforce 5D1  ABPF-EN000  \
# 1             2  Absolute Powerforce 5D1  ABPF-EN001
# 2             3  Absolute Powerforce 5D1  ABPF-EN002
# 3             4  Absolute Powerforce 5D1  ABPF-EN003
# 4             5  Absolute Powerforce 5D1  ABPF-EN004
# ...         ...                      ...         ...
# 3185       3186  The Lost Millennium GX1   TLM-EN060
# 3186       3187  The Lost Millennium GX1   TLM-ENSE1
# 3187       3188  The Lost Millennium GX1   TLM-ENSE2
# 3188       3189  The Lost Millennium GX1   TLM-ENSE3
# 3189       3190  The Lost Millennium GX1   TLM-ENSE4
#
#                                     card_name       card_type card_rarity
# 0                     Gravekeeper's Priestess  Effect Monster  Super Rare  \
# 1                                  Unicycular  Normal Monster      Common
# 2                                     Bicular  Effect Monster      Common
# 3                                    Tricular  Effect Monster      Common
# 4                              Drill Synchron   Tuner Monster        Rare
# ...                                       ...             ...         ...
# 3185                                Lone Wolf            Trap      Common
# 3186                      Invader of Darkness  Effect Monster  Ultra Rare
# 3187  Chaos Emperor Dragon - Envoy of the End  Effect Monster  Ultra Rare
# 3188                           Mazera DeVille  Effect Monster  Ultra Rare
# 3189                        The End of Anubis  Effect Monster  Ultra Rare
#
#      card_attribute card_sub_type card_level card_attack card_defense
# 0              Dark   Spellcaster        3.0      1000.0       1500.0  \
# 1             Earth       Machine        1.0       100.0        100.0
# 2             Earth       Machine        2.0       200.0        200.0
# 3             Earth       Machine        3.0       300.0        300.0
# 4             Earth       Machine        3.0       800.0        300.0
# ...             ...           ...        ...         ...          ...
# 3185                   Continuous        nan         nan          nan
# 3186           Dark         Fiend        8.0      2900.0       2500.0
# 3187           Dark        Dragon        8.0      3000.0       2500.0
# 3188           Dark         Fiend        8.0      2800.0       2300.0
# 3189           Dark         Fiend        6.0      2500.0          0.0
#
#                                               card_text
# 0     The field is treated as "Necrovalley". If ther...
# 1     The third of the brothers, following Tricular ...
# 2     When this card is destroyed by battle, you can...
# 3     When this card is destroyed by battle, you can...
# 4     While you control this face-up card, during ea...
# ...                                                 ...
# 3185  "You can only activate this card if there is o...
# 3186  "While this card is face-up on the field, your...
# 3187  "This card cannot be Normal Summoned or Set. T...
# 3188  "This card cannot be Normal Summoned or Set.  ...
# 3189  "While this card is face-up on the field, all ...
#
# [3190 rows x 12 columns]
